# %%
from sphinx.addnodes import index
import pandas as pd
from sqlalchemy import create_engine

conn = create_engine('mysql+pymysql://root:000000@172.17.20.103:3306/mysql')
data = pd.read_sql('select * from user', conn)
data

# %%
import pandas as pd
from sqlalchemy import create_engine, false

conn = create_engine('mysql+pymysql://root:000000@localhost:3306/test')
df = pd.read_excel(r"C:\Users\garry\Documents\WXWork\1688856475637991\Cache\File\2025-04\4月数据源(1).xlsx")


df.to_sql('motor_storage',conn,if_exists='append',index=False)
# Out:
# 78

# %%
import pandas as pd
from sqlalchemy import create_engine

conn = create_engine('mysql+pymysql://root:000000@localhost:3306/test')
# df = pd.read_excel(r"C:\Users\garry\Downloads\3月电动牙刷产能报表-白班 - 2025.xlsx")
df = pd.read_excel(r"C:\Users\garry\Desktop\4月电动牙刷产能报表-白班 - 2025.xlsx")


df.to_sql('motor_exception_wks',conn,if_exists='append',index=False)
# Out:
# 23

# %%
import pandas as pd
from sqlalchemy import create_engine

conn = create_engine('mysql+pymysql://root:000000@localhost:3306/test')
df = pd.read_excel(r"C:\Users\garry\Downloads\生产入库单_2025031914323023_2340002.xlsx")

df['日期'] = pd.to_datetime(df['日期']).dt.date
df.to_sql('zz_storage',conn,if_exists='replace')

df

# %%
import pandas as pd
from sqlalchemy import create_engine

conn = create_engine('mysql+pymysql://root:000000@localhost:3306/test')
df = pd.read_excel(r"C:\Users\garry\Downloads\成型4月报表(数据)(2)(1).xlsx")


df.to_sql('shape_scrap',conn,if_exists='append',index=False)
# Out:
# 33

# %%
import pandas as pd
from sqlalchemy import create_engine

conn = create_engine('mysql+pymysql://root:000000@localhost:3306/test')
df = pd.read_excel(r"C:\Users\garry\Downloads\组装部1月份数据.xlsx")

df['日期'] = pd.to_datetime(df['日期']).dt.date
df.to_sql('zz_scrap',conn,if_exists='replace')

df

# %%
import pandas as pd
over30day = pd.read_excel(r"C:\Users\garry\Downloads\瑞云寄修积压_20250324.xlsx")

# %%
over30day['检测时间'] = pd.to_datetime(over30day['检测时间'])

# %%
from datetime import datetime
over30 = over30day.copy()
over30 = over30.query("维修完成时间.isnull() and 申请类别 == '寄修/返修'").copy()
over30['时差'] = (datetime.now() - over30['检测时间']).dt.days
over30['时段'] = pd.cut(over30['时差'],bins=[0,7,15,30,2048],labels=["0-7天内",'7-15天内','15-30天内','超30天'])
over30.to_excel("12月至今时段单据.xlsx",index=False)

# %%
import pandas as pd
df = pd.read_excel(r"E:\业务量BI数据\业务量数据.xlsx")
df.型号.value_counts()

# %%
data = df.query('年份 == 2024 or 年份 == 2025')
data = data.groupby(['年月','型号'])[['退换进仓量','销售量']].sum().reset_index()
data['退换率'] = data['退换进仓量']/data['销售量']

data = data.query("型号 != 'LF01' and 型号 != 'LF02'").copy()
data = data.query("退换进仓量 >10 and 销售量 > 10").copy()
data = data.query("退换率.notnull()")
data['标准差'] = data['退换率']
data = data.groupby('型号').agg({'退换率':'mean','标准差':'std'}).reset_index()
data

# %%
import os

def get_all_file_paths(directory):
    """
    遍历指定目录，获取所有文件的完整路径。
    
    参数:
        directory (str): 需要遍历的目录路径。
        
    返回:
        list: 包含所有文件完整路径的列表。
    """
    file_paths = []
    
    try:
        # 遍历目录中的每一个文件和子目录
        for root, dirs, files in os.walk(directory):
            for file in files:
                print(root,dirs,file)
                # 拼接完整的文件路径
                file_path = os.path.join(root, file)
                file_paths.append(file_path)
    except PermissionError:
        print(f"权限不足，无法访问目录：{directory}")
    except FileNotFoundError:
        print(f"目录不存在：{directory}")
    
    return file_paths

if __name__ == "__main__":
    # 指定需要遍历的目录

    
    # 获取所有文件路径
    all_files = get_all_file_paths("E:\Dev\stone_Bot\快递100单")
    
    # 打印所有文件路径
    print("\n所有文件路径：")
    for file_path in all_files:
        print(file_path)
# Out:
# E:\Dev\stone_Bot\快递100单 [] 2025.3.4.txt
# E:\Dev\stone_Bot\快递100单 [] 2025040215282043788968.txt
# E:\Dev\stone_Bot\快递100单 [] 2025040216365078568330.txt
# E:\Dev\stone_Bot\快递100单 [] 2025040216373352766162.txt
# E:\Dev\stone_Bot\快递100单 [] 2025040216380374752134.txt
# E:\Dev\stone_Bot\快递100单 [] 2025040216384786355298.txt
# E:\Dev\stone_Bot\快递100单 [] 2025040216392950413290.txt
# E:\Dev\stone_Bot\快递100单 [] 2025040216395944665924.txt
# E:\Dev\stone_Bot\快递100单 [] 2025040216403176258405.txt
# E:\Dev\stone_Bot\快递100单 [] 2025040216405363711553.txt
# E:\Dev\stone_Bot\快递100单 [] 2025040216411148031105.txt
#
# 所有文件路径：
# E:\Dev\stone_Bot\快递100单\2025.3.4.txt
# E:\Dev\stone_Bot\快递100单\2025040215282043788968.txt
# E:\Dev\stone_Bot\快递100单\2025040216365078568330.txt
# E:\Dev\stone_Bot\快递100单\2025040216373352766162.txt
# E:\Dev\stone_Bot\快递100单\2025040216380374752134.txt
# E:\Dev\stone_Bot\快递100单\2025040216384786355298.txt
# E:\Dev\stone_Bot\快递100单\2025040216392950413290.txt
# ...

# %%
import pandas as pd
ml = []
for i in all_files:
    with open(i,'r',encoding='utf-8') as f:
        data = f.readlines()
        for i in data:
            x = i.split('|')
            info = {'id':x[2],'status':x[4]}
            ml.append(info)
pd.DataFrame(ml).to_csv('rs.csv',index=False)

# %%
with open(all_files[1],'r',encoding='utf-8') as f:
    data = f.readlines()
    for i in data:
        print(i.split('|')[2])
# Out:
# 单号
# 772038288321735
# 773341749383692
# 773341748910489
# 773341749618956
# 773341681029875
# 777287662031429
# 777287623171465
# 777287623202487
# 777287623212665
# 777287616962258
# 770237078198812
# 770237003718312
# 777287479009575
# 770237073516479
# 770237073806738
# 770237076483874
# 770237071893166
# 770237072631328
# 770237034439241
# 773341692890951
# 773341691649015
# 772038221965972
# 772038252508839
# 772038276692837
# 772038218307178
# 772038258450993
# 777287874020883
# 770014403548897
# 770236839554351
# 770014415594385
# 770236919888299
# 777287855207666
# 770236822690714
# 777286668125624
# 777286707620983
# 770236834564454
# 772038237593359
# 772038238500460
# 772038230502022
# 773341326048609
# 777286862241184
# 777286862112491
# 777286725688406
# 777286725688807
# 777286725668038
# 770236762731150
# 773341325641567
# 772038143871710
# 770236780249365
# 770236779789324
# 770236758837669
# 777286741523800
# 770236759312615
# 770236760137864
# 777286754333868
# ...

# %%
import pandas as pd
jdie = pd.read_excel(r"C:\Users\garry\Desktop\仓库.xlsx")
ys = pd.read_excel(r"C:\Users\garry\Desktop\仓库.xlsx", sheet_name='牙刷')
fj = pd.read_excel(r"C:\Users\garry\Desktop\仓库.xlsx", sheet_name='风机')

# %%
df = pd.concat([ys,fj])
df = df.drop_duplicates(subset=['快递单号'])
kinde = jdie[['运单号','物料编码','型号','产品']]
data = pd.merge(df, kinde, how='outer', left_on='快递单号',right_on='运单号')
data.fillna("-").to_excel('匹配.xlsx',index=False)

# %%
import requests
import pandas as pd
import schedule
import time
from sqlalchemy import create_engine
from typing import Dict, List, Optional
import logging
import re

from xlwings import sheets

# 配置日志
logging.basicConfig(level=logging.INFO)
logger = logging.getLogger(__name__)

class FeishuSpreadsheetManager:
    def __init__(self, spreadsheet_tokens: List[str], db_uri: str = None):
        """
        飞书表格管理器
        :param spreadsheet_tokens: 电子表格token列表
        :param db_uri: 数据库连接URI (示例: sqlite:///data.db)
        """
        self.app_id = "cli_a7e1e09d72fe500e"
        self.app_secret = "sIsx3hT20I4oQ2lrq0ydAf04LTmaKxP7"
        self.spreadsheet_tokens = spreadsheet_tokens
        self.session = requests.Session()
        self.access_token = self._get_access_token()
        self.db_engine = create_engine(db_uri) if db_uri else None
        
        # 配置请求头
        self.session.headers.update({
            "Authorization": f"Bearer {self.access_token}",
            "Content-Type": "application/json"
        })

    def _get_access_token(self, retries: int = 3) -> str:
        """获取租户访问令牌（带重试机制）"""
        url = "https://open.feishu.cn/open-apis/auth/v3/tenant_access_token/internal"
        payload = {"app_id": self.app_id, "app_secret": self.app_secret}
        
        for attempt in range(retries):
            try:
                response = self.session.post(url, json=payload)
                response.raise_for_status()
                data = response.json()
                if data.get("code") == 0:
                    return data["tenant_access_token"]
                logger.error(f"获取token失败: {data.get('msg')}")
            except Exception as e:
                logger.warning(f"获取token重试中 ({attempt+1}/{retries}): {str(e)}")
                time.sleep(2**attempt)
        raise Exception("无法获取访问令牌")

    def _get_spreadsheet_info(self, spreadsheet_token: str) -> Dict:
        """获取电子表格元数据（修正后的正确API）"""
        url = f"https://open.feishu.cn/open-apis/sheets/v3/spreadsheets/{spreadsheet_token}"
        try:
            response = self.session.get(url)
            response.raise_for_status()
            data = response.json()
            if data.get("code") == 0:
                return data["data"]["spreadsheet"]
            raise Exception(f"API错误: {data.get('msg')}")
        except Exception as e:
            logger.error(f"获取表格元数据失败: {str(e)}")
            return {"title": f"Spreadsheet_{spreadsheet_token[-6:]}"}

    def _list_sheets(self, spreadsheet_token: str) -> List[Dict]:
        """获取工作表列表（正确API）"""
        url = f"https://open.feishu.cn/open-apis/sheets/v3/spreadsheets/{spreadsheet_token}/sheets/query"
        try:
            response = self.session.get(url)
            response.raise_for_status()
            data = response.json()
            if data.get("code") == 0:
                return data["data"]["sheets"]
            raise Exception(f"API错误: {data.get('msg')}")
        except Exception as e:
            logger.error(f"获取工作表列表失败: {str(e)}")
            return []

    def _read_sheet_data(self, spreadsheet_token: str, sheet_id: str, range: str) -> pd.DataFrame:
        """读取工作表数据"""
        url = f"https://open.feishu.cn/open-apis/sheets/v2/spreadsheets/{spreadsheet_token}/values/{sheet_id}!{range}"
        try:
            response = self.session.get(url)
            response.raise_for_status()
            data = response.json()
            if data.get("code") == 0:
                values = data["data"]["valueRange"].get("values", [])
                if len(values) > 1:
                    return pd.DataFrame(values[1:], columns=values[0])
                return pd.DataFrame()
            raise Exception(f"API错误: {data.get('msg')}")
        except Exception as e:
            logger.error(f"读取数据失败: {str(e)}")
            return pd.DataFrame()

    def _get_valid_table_name(self, name: str) -> str:
        """生成合法表名"""
        # 替换非法字符
        clean_name = re.sub(r'[^a-zA-Z0-9_]', '_', name)
        # 确保以字母开头
        if not clean_name[0].isalpha():
            clean_name = 'tbl_' + clean_name
        return clean_name.lower()[:63]

    def read_all_data(self, range: str = "A:BT") -> Dict[str, pd.DataFrame]:
        """
        读取所有电子表格数据
        :return: {表格名_工作表名: DataFrame}
        """
        all_data = {}
        
        for token in self.spreadsheet_tokens:
            try:
                # 获取表格信息
                spreadsheet_info = self._get_spreadsheet_info(token)
                spreadsheet_name = spreadsheet_info.get("title", f"spreadsheet_{token[-6:]}")
                
                # 获取工作表列表
                sheets = self._list_sheets(token)
                # sheet_ids = list(map(lambda x:{x['title']:x['sheet_id']},sheets))
                
                logger.info(f"在表格 {spreadsheet_name} 中找到 {len(sheets)} 个工作表")
                
                for sheet in sheets:
                    sheet_name = sheet["title"]
                    combined_name = f"{spreadsheet_name[4:7]}_{sheet_name}"
                    
                    # 读取数据
                    df = self._read_sheet_data(token, sheet["sheet_id"], range)
                    if not df.empty:
                        # 时间格式化
                        df = df.drop(columns=[None])
                        try:
                            df['日期'] = pd.to_datetime(df['日期'],unit='D', origin='1899-12-30').dt.date
                        except Exception as e:
                            print(e)
                        all_data[combined_name] = df
                        logger.info(f"成功读取 {combined_name} {df.shape[0]}行,{df.shape[1]} 列)")
                    else:
                        logger.warning(f"工作表 {combined_name} 无数据")
                logger.info('='*30)
            except Exception as e:
                logger.error(f"处理表格 {token} 失败: {str(e)}")
                continue
                
        return all_data

    def save_to_database(self, data: Dict[str, pd.DataFrame], if_exists: str = 'replace'):
        """存储到数据库"""
        if not self.db_engine:
            raise Exception("未配置数据库连接")
        
        try:
            for raw_name, df in data.items():
                table_name = self._get_valid_table_name(raw_name)
                df.to_sql(
                    name=table_name,
                    con=self.db_engine,
                    index=False,
                    if_exists=if_exists
                )
                logger.info(f"已保存 {table_name} {df.shape[0]}行,{df.shape[1]} 列)")
        except Exception as e:
            logger.error(f"数据库保存失败: {str(e)}")
            raise

    def auto_sync(self, interval: int = 3600):
        """启动自动同步"""
        schedule.every(interval).seconds.do(self._sync_job)
        logger.info(f"自动同步已启动，间隔 {interval} 秒")
        
        while True:
            schedule.run_pending()
            time.sleep(1)

    def _sync_job(self):
        """执行同步任务"""
        try:
            data = self.read_all_data()
            if self.db_engine:
                self.save_to_database(data)
            logger.info("同步任务完成")
        except Exception as e:
            logger.error(f"同步失败: {str(e)}")

if __name__ == '__main__':
    # TOKENS 电机 成型 组装
    SPREADSHEET_TOKENS = ['DiWssnFVLhcymFtJWnlctwVMnPf', 'RYcuszk7thaneqtqMioc3hQonxh', 'LiScsSTzChb1B7tX2OUcGuB2nyc']
    SPREADSHEET_TOKENS = ['LiScsSTzChb1B7tX2OUcGuB2nyc'] 
    DB_URI = 'mysql+pymysql://root:000000@127.0.0.1:3306/test'  # SQLite示例
    
    # 初始化管理器
    manager = FeishuSpreadsheetManager(
        spreadsheet_tokens=SPREADSHEET_TOKENS,
        db_uri=DB_URI
    )
    
    data = manager.read_all_data()
    data   
    # 执行一次同步
    # try:
    #     data = manager.read_all_data()
    #     manager.save_to_database(data)
    # except Exception as e:
    #     logger.error(f"初始化同步失败: {str(e)}")
    
    # 启动定时同步（每小时一次）
    # manager.auto_sync(interval=3600)
# Out:
# INFO:__main__:在表格 石岩BI组装部源数据 中找到 4 个工作表
# INFO:__main__:成功读取 组装部_生产数据 336行,26 列)
# INFO:__main__:成功读取 组装部_异常工时 10行,13 列)
# INFO:__main__:成功读取 组装部_报废 2390行,20 列)
# INFO:__main__:成功读取 组装部_入库 2171行,18 列)
# INFO:__main__:==============================

# %%
# data['组装部_生产数据'].to_sql('zz',DB_URI,if_exists='append', index=False)
data['组装部_入库']
# Out:
#               单据编号          日期 单据状态          入库组织          生产组织       总成本  \
# 0     SCRK00586009  2025-05-09  已审核  深圳术叶创新科技有限公司  深圳徕芬智造科技有限公司         0
# 1     SCRK00586008  2025-05-09  已审核  深圳术叶创新科技有限公司  深圳徕芬智造科技有限公司         0
# 2     SCRK00585998  2025-05-09  已审核  深圳术叶创新科技有限公司  深圳徕芬智造科技有限公司         0
# 3     SCRK00585997  2025-05-09  已审核  深圳术叶创新科技有限公司  深圳徕芬智造科技有限公司         0
# 4     SCRK00585996  2025-05-09  已审核  深圳术叶创新科技有限公司  深圳徕芬智造科技有限公司         0
# ...            ...         ...  ...           ...           ...       ...
# 2166  SCRK00494768  2025-01-03  已审核  深圳术叶创新科技有限公司  深圳徕芬智造科技有限公司  21912.25
# 2167  SCRK00494765  2025-01-03  已审核  深圳术叶创新科技有限公司  深圳徕芬智造科技有限公司  21912.25
# 2168  SCRK00494762  2025-01-03  已审核  深圳术叶创新科技有限公司  深圳徕芬智造科技有限公司  21912.25
# 2169  SCRK00494357  2025-01-02  已审核  深圳术叶创新科技有限公司  深圳徕芬智造科技有限公司  21912.25
# 2170  SCRK00494356  2025-01-02  已审核  深圳术叶创新科技有限公司  深圳徕芬智造科技有限公司  21912.25
#
#                    物料编码                                    物料名称  \
# ...

# %%
x = data['石岩BI成型部源数据 _生产数据'].copy()
# x = x.drop(columns=[None])
# dates = pd.to_datetime('1899-12-30') + pd.to_timedelta(excel_dates, unit='D')
x['日期'] = pd.to_datetime(x['日期'],unit='D', origin='1899-12-30').dt.date
x

# %%
import pandas as pd 
all_sheets = pd.read_excel(r"C:\Users\garry\Desktop\你懂的BOM.xlsx",sheet_name=None)

all_sku = all_sheets['整机编码']


# change 2
boms = all_sheets['MINI LITE物料BOM']
errors_bom = all_sheets['MINI LITE故障BOM']

cureency_components = all_sheets['物料分类']

normal = boms.query('类型 == "辅料" or 类型 == "通用"')
def update_component(component_name, source_df=normal):
    print(component_name)
    mask = boms['标识'] == component_name
    if mask.any():
        code_value = source_df.loc[mask, '新编码'].iloc[0]  # 取第一个匹配值
        errors_bom.loc[errors_bom[component_name].notnull(), component_name] = code_value

    
# change 1
name = 'MINI LITE通用'
print(len(cureency_components[name].dropna()))
for comp in cureency_components[name].dropna():
    update_component(comp)
# change 1
SPU = 'MINI'
product_model = all_sku.query(f'SPU == "{SPU}"')
# 专用部件编码更新
def update_component_specical(color,special_components,sku,spu,cplx,zjmc,code):
    
    source_df = boms.query('类型.str.contains(@color)',engine='python')
    new_df = errors_bom.copy()
    new_df.insert(0,'SKU',sku)
    new_df.insert(0,'SPU',spu,)
    new_df.insert(0,'产品类型',cplx)
    new_df.insert(0,'整机名称',zjmc)
    new_df.insert(0,'整机编码',code)

    for comp in special_components:
        mask = boms['标识'] == comp
        if mask.any():
            print(color,comp)
            try:
                code_value = source_df.loc[mask, '新编码'].iloc[0]  # 取第一个匹配值
            except Exception as e:
                code_value = None
                print(e)
            print(code_value)
            if code_value:
                new_df.loc[errors_bom[comp].notnull(), comp] = code_value
            else:
                new_df.loc[errors_bom[comp].notnull(), comp] = None
    return new_df

# change 2
pd.concat(
    [update_component_specical(color,cureency_components['MINI LITE专用'].dropna(),sku,spu,cplx,zjmc,code) for color,sku,spu,cplx,zjmc,code in zip(product_model['颜色'],product_model['SKU'],product_model['SPU'],product_model['产品类型'],product_model['整机名称'],product_model['整机编码'])],
    ignore_index=True
).to_excel('./处理输出/MINI-Lite寄修BOM.xlsx',index=False)

# %%
all_sheets = pd.read_excel(r"C:\Users\garry\Desktop\你懂的BOM.xlsx",sheet_name=None)
boms = list(all_sheets.keys())[3:15]
cureency_components = all_sheets['物料分类']
bill = list(cureency_components.columns)[:12]
bill = list(zip(bill[::2], bill[1::2]))
bill[0][0]
# Out:
# '03SE专用'

# %%
# 专用部件编码更新
def update_component_specical(color,special_components,sku,spu,cplx,zjmc,code):
    
    source_df = boms.query('类型.str.contains(@color)',engine='python')
    new_df = errors_bom.copy()
    new_df.insert(0,'SKU',sku)
    new_df.insert(0,'SPU',spu,)
    new_df.insert(0,'产品类型',cplx)
    new_df.insert(0,'整机名称',zjmc)
    new_df.insert(0,'整机编码',code)

    for comp in special_components:
        mask = boms['标识'] == comp
        if mask.any():
            print(color,comp)
            try:
                code_value = source_df.loc[mask, '新编码'].iloc[0]  # 取第一个匹配值
            except Exception as e:
                code_value = None
                print(e)
            print(code_value)
            if code_value:
                new_df.loc[errors_bom[comp].notnull(), comp] = code_value
            else:
                new_df.loc[errors_bom[comp].notnull(), comp] = None
    return new_df

# change 2
pd.concat(
    [update_component_specical(color,cureency_components['MINI LITE专用'].dropna(),sku,spu,cplx,zjmc,code) for color,sku,spu,cplx,zjmc,code in zip(product_model['颜色'],product_model['SKU'],product_model['SPU'],product_model['产品类型'],product_model['整机名称'],product_model['整机编码'])],
    ignore_index=True
).to_excel('./处理输出/MINI-Lite寄修BOM.xlsx',index=False)

# %%
import pandas as pd
df = pd.DataFrame({
    'region': ['North']*12 + ['South']*12,
    'month': list(range(1,13))*2,
    'sales': [i*100 for i in range(12)] + [i*80 for i in range(12)]
})
df
# Out:
#    region  month  sales
# 0   North      1      0
# 1   North      2    100
# 2   North      3    200
# 3   North      4    300
# 4   North      5    400
# 5   North      6    500
# 6   North      7    600
# 7   North      8    700
# 8   North      9    800
# 9   North     10    900
# 10  North     11   1000
# 11  North     12   1100
# 12  South      1      0
# 13  South      2     80
# 14  South      3    160
# 15  South      4    240
# 16  South      5    320
# 17  South      6    400
# 18  South      7    480
# 19  South      8    560
# 20  South      9    640
# 21  South     10    720
# 22  South     11    800
# 23  South     12    880
